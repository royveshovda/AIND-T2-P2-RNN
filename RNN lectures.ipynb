# %%
x = [[1], [3], [5], [7], [9], [11], [13]]
y = [[3], [5], [7], [9], [11], [13], [15]]

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

model = Sequential()
model.add(Dense(1, input_dim=1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(x, y, epochs=3000, batch_size=3, verbose=0)
# Out:
# Using TensorFlow backend.

# %%
model.get_weights()
# Out:
# [array([[ 1.00102937]], dtype=float32), array([ 1.99084091], dtype=float32)]

# %%
import numpy as np
model.predict(np.array([5]))
# Out:
# array([[ 6.99598789]], dtype=float32)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

s1_0 = 0.5
w0 = 1

N = list(range(1,51))

# %%
def f(s, w_):
    return (w_ * s) - (w_ * (s**2))

# %%
s1_0 = 0.5
w0 = 1

Y0 = [s1_0]
value = s1_0
for i in range(2,51):
    value = f(value, w0)
    Y0.append(value)

# %%
plt.plot(N, Y0)

# %%
s1_1 = 0.5
w1 = 3

Y1 = [s1_1]
value = s1_1
for i in range(2,51):
    value = f(value, w1)
    Y1.append(value)

# %%
plt.plot(N, Y1)

# %%
s1_2 = 0.0001
w2 = 4

Y2 = [s1_2]
value = s1_2
for i in range(2,51):
    value = f(value, w2)
    Y2.append(value)

# %%
plt.plot(N, Y2)
